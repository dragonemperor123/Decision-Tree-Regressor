# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/srinivasav22/Graduate-Admission-Prediction/master/Admission_Predict_Ver1.1.csv")

# %%
df.columns = [c.replace(' ', '_') for c in df.columns]

# %%
df
# Out:
#      Serial_No.  GRE_Score  TOEFL_Score  University_Rating  SOP  LOR_  CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 495         496        332          108                  5  4.5   4.0  9.02
# 496         497        337          117                  5  5.0   5.0  9.87
# 497         498        330          120                  5  4.5   5.0  9.56
# 498         499        312          103                  4  4.0   5.0  8.43
# 499         500        327          113                  4  4.5   4.5  9.04
#
#      Research  Chance_of_Admit_
# ...

# %%
df.columns = [c.replace(' ', '_') for c in df.columns]

# %%
df.head()
# Out:
#    Serial_No.  GRE_Score  TOEFL_Score  University_Rating  SOP  LOR_  CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance_of_Admit_
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
df.columns
# Out:
# Index(['Serial_No.', 'GRE_Score', 'TOEFL_Score', 'University_Rating', 'SOP',
#        'LOR_', 'CGPA', 'Research', 'Chance_of_Admit_'],
#       dtype='object')

# %%
df.describe().T
# Out:
#                    count       mean         std     min       25%     50%  \
# Serial_No.         500.0  250.50000  144.481833    1.00  125.7500  250.50
# GRE_Score          500.0  316.47200   11.295148  290.00  308.0000  317.00
# TOEFL_Score        500.0  107.19200    6.081868   92.00  103.0000  107.00
# University_Rating  500.0    3.11400    1.143512    1.00    2.0000    3.00
# SOP                500.0    3.37400    0.991004    1.00    2.5000    3.50
# LOR_               500.0    3.48400    0.925450    1.00    3.0000    3.50
# CGPA               500.0    8.57644    0.604813    6.80    8.1275    8.56
# Research           500.0    0.56000    0.496884    0.00    0.0000    1.00
# Chance_of_Admit_   500.0    0.72174    0.141140    0.34    0.6300    0.72
#
#                       75%     max
# Serial_No.         375.25  500.00
# GRE_Score          325.00  340.00
# TOEFL_Score        112.00  120.00
# University_Rating    4.00    5.00
# SOP                  4.00    5.00
# ...

# %%
df.columns
# Out:
# Index(['Serial_No.', 'GRE_Score', 'TOEFL_Score', 'University_Rating', 'SOP',
#        'LOR_', 'CGPA', 'Research', 'Chance_of_Admit_'],
#       dtype='object')

# %%
df.duplicated().sum()
# Out:
# 0

# %%
X=df.drop("Chance_of_Admit_",axis=1)

# %%
y=df["Chance_of_Admit_"]

# %%
X
# Out:
#      Serial_No.  GRE_Score  TOEFL_Score  University_Rating  SOP  LOR_  CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 495         496        332          108                  5  4.5   4.0  9.02
# 496         497        337          117                  5  5.0   5.0  9.87
# 497         498        330          120                  5  4.5   5.0  9.56
# 498         499        312          103                  4  4.0   5.0  8.43
# 499         500        327          113                  4  4.5   4.5  9.04
#
#      Research
# 0           1
# 1           1
# ...

# %%
y
# Out:
# 0      0.92
# 1      0.76
# 2      0.72
# 3      0.80
# 4      0.65
#        ...
# 495    0.87
# 496    0.96
# 497    0.93
# 498    0.73
# 499    0.84
# Name: Chance_of_Admit_, Length: 500, dtype: float64

# %%
from sklearn.model_selection import train_test_split,GridSearchCV

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.33,random_state=10)

# %%
X_train
# Out:
#      Serial_No.  GRE_Score  TOEFL_Score  University_Rating  SOP  LOR_  CGPA  \
# 194         195        316          109                  3  3.5   3.0  8.76
# 396         397        325          107                  3  3.0   3.5  9.11
# 52           53        334          116                  4  4.0   3.0  8.00
# 27           28        298           98                  2  1.5   2.5  7.50
# 460         461        319          105                  4  4.0   4.5  8.66
# ..          ...        ...          ...                ...  ...   ...   ...
# 320         321        317          106                  3  4.0   3.5  8.50
# 15           16        314          105                  3  3.5   2.5  8.30
# 484         485        317          106                  3  3.5   3.0  7.89
# 125         126        300          100                  3  2.0   3.0  8.66
# 265         266        313          102                  3  2.5   2.5  8.68
#
#      Research
# 194         0
# 396         1
# ...

# %%
X_test
# Out:
#      Serial_No.  GRE_Score  TOEFL_Score  University_Rating  SOP  LOR_  CGPA  \
# 151         152        332          116                  5  5.0   5.0  9.28
# 424         425        325          114                  5  4.0   5.0  9.46
# 154         155        326          108                  3  3.0   3.5  8.89
# 190         191        324          111                  5  4.5   4.0  9.16
# 131         132        303          105                  5  5.0   4.5  8.65
# ..          ...        ...          ...                ...  ...   ...   ...
# 147         148        326          114                  3  3.0   3.0  9.11
# 326         327        299          100                  3  2.0   2.0  8.02
# 384         385        340          113                  4  5.0   5.0  9.74
# 257         258        324          100                  3  4.0   5.0  8.64
# 113         114        320          110                  2  4.0   3.5  8.56
#
#      Research
# 151         1
# 424         1
# ...

# %%
y_train
# Out:
# 194    0.77
# 396    0.84
# 52     0.78
# 27     0.44
# 460    0.77
#        ...
# 320    0.75
# 15     0.54
# 484    0.73
# 125    0.64
# 265    0.71
# Name: Chance_of_Admit_, Length: 335, dtype: float64

# %%
y_test
# Out:
# 151    0.94
# 424    0.91
# 154    0.80
# 190    0.90
# 131    0.77
#        ...
# 147    0.83
# 326    0.63
# 384    0.96
# 257    0.78
# 113    0.72
# Name: Chance_of_Admit_, Length: 165, dtype: float64

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import cross_val_score

# %%
regressor = DecisionTreeRegressor(random_state=0)
cross_val_score(regressor, X, y, cv=10)
# Out:
# array([0.4488078 , 0.41422383, 0.67634979, 0.73083816, 0.77877941,
#        0.70404554, 0.55433761, 0.67867242, 0.6844898 , 0.78391988])

# %%
regressor.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
regressor.score(X_train,y_train)
# Out:
# 1.0

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,explained_variance_score,r2_score

# %%
y_scpred=regressor.predict(X_train)

# %%
print(r2_score(y_train,y_scpred))
# Out:
# 1.0

# %%
print(mean_squared_error(y_train,y_scpred))
# Out:
# 4.047327405518251e-34

# %%
print(mean_absolute_error(y_train,y_scpred))
# Out:
# 3.645508439067678e-18

# %%
import numpy as np
print(np.sqrt(mean_squared_error(y_train,y_scpred)))
# Out:
# 2.0117970587308876e-17

# %%
y_tscpred=regressor.predict(X_test)

# %%
#plt.scatter(X[:, 1], y, color = 'red')
#plt.plot(X, regressor.predict(X), color = 'blue')
#plt.title('Check It (Regression Model)')
#plt.xlabel('Position level')
#plt.ylabel('Salary')
#plt.show()

# %%
X.shape
# Out:
# (500, 8)

# %%
y.shape
# Out:
# (500,)

# %%
import matplotlib.pyplot as plt

# %%
plt.rcParams['figure.figsize']=(10,6)
x_ax=range(len(X_test))
plt.plot(x_ax,y_test,label='Observed',color='k',linestyle='-')
plt.plot(x_ax,y_tscpred,label='Predicted',color='k',linestyle='--')

# %%
plt.plot(x_ax,y_tscpred,label='Predicted',color='k',linestyle='--')

# %%
from yellowbrick.regressor import PredictionError

# %%
visualizer = PredictionError(regressor)
visualizer.fit(X_train,y_train)
visualizer.score(X_test,y_test)
visualizer.poof()
# Out:
# E:\Anaconda\lib\site-packages\sklearn\base.py:441: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# <AxesSubplot:title={'center':'Prediction Error for DecisionTreeRegressor'}, xlabel='$y$', ylabel='$\\hat{y}$'>

# %%
from yellowbrick.regressor import ResidualsPlot

# %%
visualizer = ResidualsPlot(regressor)
visualizer.fit(X_train,y_train)
visualizer.score(X_test,y_test)
visualizer.poof()
# Out:
# E:\Anaconda\lib\site-packages\sklearn\base.py:441: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# <AxesSubplot:title={'center':'Residuals for DecisionTreeRegressor Model'}, xlabel='Predicted Value', ylabel='Residuals'>

# %%
print(mean_absolute_error(y_test,y_tscpred))
# Out:
# 0.053818181818181814

# %%
print(mean_squared_error(y_test,y_tscpred))
# Out:
# 0.006023030303030302

# %%
from sklearn.model_selection import cross_val_score

# %%
score_train=cross_val_score(regressor,X_train,y_train,scoring='neg_mean_squared_error',cv=10)

# %%
score_train
# Out:
# array([-0.00603529, -0.01162353, -0.00352353, -0.00735   , -0.01317059,
#        -0.00717879, -0.0095303 , -0.0077    , -0.00826061, -0.01609394])

# %%
from numpy import absolute
np.mean(score_train)
# Out:
# -0.009046657754010696

# %%
sc_train=absolute(score_train)

# %%
np.mean(sc_train)
# Out:
# 0.009046657754010696

# %%
score_test=cross_val_score(regressor,X_test,y_test,scoring='neg_mean_squared_error',cv=10)

# %%
sc_test=absolute(score_test)

# %%
sc_test
# Out:
# array([0.00291176, 0.00327647, 0.01043529, 0.00529412, 0.00545882,
#        0.01501875, 0.01039375, 0.0021875 , 0.00770625, 0.007475  ])

# %%
np.mean(sc_test)
# Out:
# 0.0070157720588235285

# %%
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.tree import DecisionTreeRegressor
from sklearn import tree

# %%
X_col_names = list(X_train.columns)
feature_names = X_col_names

# %%
fig = plt.figure(figsize=(25,20))
_ = tree.plot_tree(regressor, feature_names=feature_names, filled=True)
